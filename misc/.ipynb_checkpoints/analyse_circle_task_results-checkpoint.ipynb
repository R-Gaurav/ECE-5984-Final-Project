# %%
import _init_paths
import consts.dir_consts as drc
from src.circle_task.train_actor_critic import get_network

import nengo
import matplotlib.pyplot as plt
import pickle

RES_DIR = drc.RESULTS_DIR+"/circle_task/"
# Out:
# 2022-05-06 21:25:37.903550: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-05-06 21:25:37.903696: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (gra395): /proc/driver/nvidia/version does not exist

# %% [markdown]
# # Run the Agent

# %%
net = get_network()
sim = nengo.Simulator(net)
sim.run(100) # Execute for 100 secs first.
# Out:
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc['progress']['progress_bar'] = 'nengo.utils.progress.TerminalProgressBar'`.
# <script>
#               (function () {
#                   var root = document.getElementById('c965b99c-cf4d-4627-a6f5-01573072b31b');
#                   var text = root.getElementsByClassName('pb-text')[0];
#                   var fill = root.getElementsByClassName('pb-fill')[0];
#
#                   text.innerHTML = 'Build finished in 0:00:01.';
#
#             fill.style.width = '100%';
#             fill.style.animation = 'pb-fill-anim 2s linear infinite';
#             fill.style.backgroundSize = '100px 100%';
#             fill.style.backgroundImage = 'repeating-linear-gradient(' +
#                 '90deg, #bdd2e6, #edf2f8 40%, #bdd2e6 80%, #bdd2e6)';
#
#
#                 fill.style.animation = 'none';
#                 fill.style.backgroundImage = 'none';
#
#               })();
#         </script>
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc['progress']['progress_bar'] = 'nengo.utils.progress.TerminalProgressBar'`.
# <script>
#               (function () {
#                   var root = document.getElementById('d8a6ded8-4f69-4999-aab0-8bc523692048');
#                   var text = root.getElementsByClassName('pb-text')[0];
#                   var fill = root.getElementsByClassName('pb-fill')[0];
#
#                   text.innerHTML = 'Simulating&hellip; 80%, ETA: 0:00:09';
#
#             if (79.637 > 0.) {
#                 fill.style.transition = 'width 0.1s linear';
#             } else {
#                 fill.style.transition = 'none';
#             }
#
#             fill.style.width = '79.637%';
#             fill.style.animation = 'none';
#             fill.style.backgroundImage = 'none'
#
#
#               })();
#         </script>

# %%
plt.plot(sim.trange(), sim.data[net.probe_reward], label="Agent's Reward")
plt.plot(sim.trange(), sim.data[net.probe_value], label="Agent's State Value")
plt.xlabel("Time (in seconds)")
plt.ylabel("Reward and State Values")
plt.legend()

# %%
# Run the Actor-Critic model for next 300 secs.
sim.run(300) # Execute for 300 seconds.
# Out:
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc['progress']['progress_bar'] = 'nengo.utils.progress.TerminalProgressBar'`.
# <script>
#               (function () {
#                   var root = document.getElementById('8c3aa536-119d-498e-9449-520727348d77');
#                   var text = root.getElementsByClassName('pb-text')[0];
#                   var fill = root.getElementsByClassName('pb-fill')[0];
#
#                   text.innerHTML = 'Simulation finished in 0:00:04.';
#
#             if (2.621 > 0.) {
#                 fill.style.transition = 'width 0.1s linear';
#             } else {
#                 fill.style.transition = 'none';
#             }
#
#             fill.style.width = '2.621%';
#             fill.style.animation = 'none';
#             fill.style.backgroundImage = 'none'
#
#
#                 fill.style.animation = 'none';
#                 fill.style.backgroundImage = 'none';
#
#               })();
#         </script>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [7], in <cell line: 2>()
#       1 # Run the Actor-Critic model for next 300 secs.
# ----> 2 sim.run(300)
#
# File ~/Documents/python-virtual-environments/drl/lib/python3.8/site-packages/nengo/simulator.py:386, in Simulator.run(self, time_in_seconds, progress_bar)
#     379 else:
#     380     logger.info(
#     381         "Running %s for %f seconds, or %d steps",
#     382         self.model.label,
#     383         time_in_seconds,
#     384         steps,
#     385     )
# --> 386     self.run_steps(steps, progress_bar=progress_bar)
#
# File ~/Documents/python-virtual-environments/drl/lib/python3.8/site-packages/nengo/simulator.py:410, in Simulator.run_steps(self, steps, progress_bar)
#     406 with ProgressTracker(
#     407     progress_bar, Progress("Simulating", "Simulation", steps)
#     408 ) as pt:
#     409     for _ in range(steps):
# --> 410         self.step()
#     411         pt.total_progress.step()
#
# File ~/Documents/python-virtual-environments/drl/lib/python3.8/site-packages/nengo/simulator.py:421, in Simulator.step(self)
#     419 try:
#     420     for step_fn in self._steps:
# --> 421         step_fn()
#     422 finally:
#     423     np.seterr(**old_err)
#
# File ~/Documents/python-virtual-environments/drl/lib/python3.8/site-packages/nengo/builder/operator.py:806, in SimPyFunc.make_step.<locals>.step_simpyfunc()
#     804 def step_simpyfunc():
#     805     args = (np.copy(x),) if x is not None else ()
# --> 806     y = fn(t.item(), *args) if t is not None else fn(*args)
#     808     if output is not None:
#     809         try:
#     810             # required since Numpy turns None into NaN
#
# File /project/6043718/rgaurav/ECE-5984-Final-Project/misc/../src/circle_task/train_actor_critic.py:58, in get_network.<locals>.softmax(t, x)
#      57 def softmax(t, x):
# ---> 58   return np.exp(x)/np.sum(np.exp(x))
#
# File <__array_function__ internals>:5, in sum(*args, **kwargs)
#
# File ~/Documents/python-virtual-environments/drl/lib/python3.8/site-packages/numpy/core/fromnumeric.py:2259, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2256         return out
#    2257     return res
# -> 2259 return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
#    2260                       initial=initial, where=where)
#
# File ~/Documents/python-virtual-environments/drl/lib/python3.8/site-packages/numpy/core/fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# KeyboardInterrupt:

# %%
print("Saving Results...")
pickle.dump(sim.data[net.probe_value],
            open(drc.RESULTS_DIR+"/circle_task/full_critic_value.p", "wb"))
pickle.dump(sim.data[net.probe_reward],
            open(drc.RESULTS_DIR+"/circle_task/full_env_rewards.p", "wb"))
pickle.dump(sim.data[net.probe_actor_choice],
            open(drc.RESULTS_DIR+"/circle_task/full_actor_choices.p", "wb"))
pickle.dump(sim.data[net.probe_actor_aprobs],
            open(drc.RESULTS_DIR+"/circle_task/full_actor_action_probs.p", "wb"))
pickle.dump(sim.trange(),
            open(drc.RESULTS_DIR+"/circle_task/sim_trange.p", "wb"))
print("Results saved! Exiting...")
# Out:
# Saving Results...
# Results saved! Exiting...

# %%
actor_action_probs = pickle.load(open(RES_DIR+"./full_actor_action_probs.p", "rb"))
actor_action_choices = pickle.load(open(RES_DIR+"./full_actor_choices.p", "rb"))
critic_value = pickle.load(open(RES_DIR+"./full_critic_value.p", "rb"))
env_rewards = pickle.load(open(RES_DIR+"./full_env_rewards.p", "rb"))
sim_trange = pickle.load(open(RES_DIR+"./sim_trange.p", "rb"))

# %% [markdown]
# # Agent's Reward

# %%
plt.figure(figsize=(14, 3))
plt.plot(sim_trange, env_rewards, label="Agent's Rewards")
plt.plot(sim_trange, critic_value, label="Agent's State Value")
plt.xlabel("Time (in seconds)")
plt.ylabel("Reward and State Values")
plt.legend()

# %%
plt.figure(figsize=(14, 3))
plt.plot(sim_trange, env_rewards, label="Agent's Rewards")
plt.xlabel("Time (in seconds)")
plt.ylabel("Reward Values")
plt.legend()

# %% [markdown]
# # Agent's Action Choices

# %%
plt.plot(actor_action_choices)
# Out:
# [<matplotlib.lines.Line2D at 0x2ac7a4b86430>,
#  <matplotlib.lines.Line2D at 0x2ac7a4b86490>]

# %%
plt.plot(actor_action_probs)
# Out:
# [<matplotlib.lines.Line2D at 0x2ac7a4bf0a60>,
#  <matplotlib.lines.Line2D at 0x2ac7a4bf0ac0>]
